# %%
import pandas as pd
import numpy as np
import math
import plotly.express as px

# %%
episodes = pd.read_parquet("../data/logs/depth_1_onehot/eval_001/depth_1/episodes.parquet")
display(episodes.head())
# Out:
#                  episode_id   model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth1-episode0  depth_1_onehot               1                R'
# 1  eval_001-depth1-episode1  depth_1_onehot               1                F'
# 2  eval_001-depth1-episode2  depth_1_onehot               1                 U
# 3  eval_001-depth1-episode3  depth_1_onehot               1                 L
# 4  eval_001-depth1-episode4  depth_1_onehot               1                L'
#
#                                          start_state  solved  total_steps  \
# 0  YYBYYBYYBOOOOOOOOOGGYGGYGGYWWGWWGWWGRRRRRRRRRW...    True            3
# 1  YYYYYYOOOWOOWOOWOOGGGGGGGGGRRRWWWWWWRRYRRYRRYB...    True            1
# 2  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...    True            3
# 3  BYYBYYBYYOOOOOOOOOYGGYGGYGGGWWGWWGWWRRRRRRRRRB...   False           50
# 4  GYYGYYGYYOOOOOOOOOWGGWGGWGGBWWBWWBWWRRRRRRRRRB...   False           50
#
#    total_reward  timeout termination_reason  \
# ...

# %%
solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['start_state'].value_counts())
# Out:
#                  episode_id   model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth1-episode0  depth_1_onehot               1                R'
# 1  eval_001-depth1-episode1  depth_1_onehot               1                F'
# 2  eval_001-depth1-episode2  depth_1_onehot               1                 U
# 5  eval_001-depth1-episode5  depth_1_onehot               1                 D
# 6  eval_001-depth1-episode6  depth_1_onehot               1                 B
#
#                                          start_state  solved  total_steps  \
# 0  YYBYYBYYBOOOOOOOOOGGYGGYGGYWWGWWGWWGRRRRRRRRRW...    True            3
# 1  YYYYYYOOOWOOWOOWOOGGGGGGGGGRRRWWWWWWRRYRRYRRYB...    True            1
# 2  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...    True            3
# 5  YYYYYYYYYOOOOOOGGGGGGGGGRRRWWWWWWWWWRRRRRRBBBB...    True            1
# 6  OOOYYYYYYOOWOOWOOWGGGGGGGGGWWWWWWRRRYRRYRRYRRB...    True            3
#
# ...

# %%
episodes = pd.read_parquet("../data/logs/depth_1_onehot/eval_001/depth_2/episodes.parquet")
display(display(episodes.head()))
# Out:
#                  episode_id   model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth2-episode0  depth_1_onehot               2              L U'
# 1  eval_001-depth2-episode1  depth_1_onehot               2              U B'
# 2  eval_001-depth2-episode2  depth_1_onehot               2               R L
# 3  eval_001-depth2-episode3  depth_1_onehot               2              B' D
# 4  eval_001-depth2-episode4  depth_1_onehot               2               D D
#
#                                          start_state  solved  total_steps  \
# 0  YYYYYYBBBYGGOOOOOORRRYGGYGGGWWGWWGWWBBWRRRRRRO...   False           50
# 1  RRGYYYYYYBBYOOYOOYOOOGGGGGGWWWWWWOOBWGGWRRWRRR...   False           50
# 2  BYGBYGBYGOOOOOOOOOYGWYGWYGWGWBGWBGWBRRRRRRRRRY...   False           50
# 3  RRRYYYYYYOOYOOYGGGGGGGGGWRROWWOWWOWWWRRWRRBBBB...   False           50
# 4  YYYYYYYYYOOOOOORRRGGGGGGBBBWWWWWWWWWRRRRRROOOB...    True            2
#
#    total_reward  timeout termination_reason  \
# ...

# %%
episodes = pd.read_parquet("../data/logs/depth_1_onehot/eval_001/depth_2/episodes.parquet")
display(episodes.head())
# Out:
#                  episode_id   model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth2-episode0  depth_1_onehot               2              L U'
# 1  eval_001-depth2-episode1  depth_1_onehot               2              U B'
# 2  eval_001-depth2-episode2  depth_1_onehot               2               R L
# 3  eval_001-depth2-episode3  depth_1_onehot               2              B' D
# 4  eval_001-depth2-episode4  depth_1_onehot               2               D D
#
#                                          start_state  solved  total_steps  \
# 0  YYYYYYBBBYGGOOOOOORRRYGGYGGGWWGWWGWWBBWRRRRRRO...   False           50
# 1  RRGYYYYYYBBYOOYOOYOOOGGGGGGWWWWWWOOBWGGWRRWRRR...   False           50
# 2  BYGBYGBYGOOOOOOOOOYGWYGWYGWGWBGWBGWBRRRRRRRRRY...   False           50
# 3  RRRYYYYYYOOYOOYGGGGGGGGGWRROWWOWWOWWWRRWRRBBBB...   False           50
# 4  YYYYYYYYYOOOOOORRRGGGGGGBBBWWWWWWWWWRRRRRROOOB...    True            2
#
#    total_reward  timeout termination_reason  \
# ...

# %%
solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['total_steps'].value_counts())
# Out:
#                    episode_id   model_version  scramble_depth  \
# 4    eval_001-depth2-episode4  depth_1_onehot               2
# 6    eval_001-depth2-episode6  depth_1_onehot               2
# 22  eval_001-depth2-episode22  depth_1_onehot               2
# 23  eval_001-depth2-episode23  depth_1_onehot               2
# 62  eval_001-depth2-episode62  depth_1_onehot               2
#
#    scramble_sequence                                        start_state  \
# 4                D D  YYYYYYYYYOOOOOORRRGGGGGGBBBWWWWWWWWWRRRRRROOOB...
# 6                R D  YYGYYGYYGOOOOOOGGWGGWGGWRRRWWWWWWBBBRRRRRRYBBY...
# 22               D D  YYYYYYYYYOOOOOORRRGGGGGGBBBWWWWWWWWWRRRRRROOOB...
# 23              R D'  YYGYYGYYGOOOOOOYBBGGWGGWOOOBBBWWWWWWRRRRRRGGWY...
# 62               R R  YYWYYWYYWOOOOOOOOOGGBGGBGGBWWYWWYWWYRRRRRRRRRG...
#
#     solved  total_steps  total_reward  timeout termination_reason  \
# 4     True            2          98.0    False             solved
# ...

# %%
episodes = pd.read_parquet("../data/logs/depth_1_onehot/eval_001/depth_1/episodes.parquet")
display(episodes.head())
# Out:
#                  episode_id   model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth1-episode0  depth_1_onehot               1                R'
# 1  eval_001-depth1-episode1  depth_1_onehot               1                F'
# 2  eval_001-depth1-episode2  depth_1_onehot               1                 U
# 3  eval_001-depth1-episode3  depth_1_onehot               1                 L
# 4  eval_001-depth1-episode4  depth_1_onehot               1                L'
#
#                                          start_state  solved  total_steps  \
# 0  YYBYYBYYBOOOOOOOOOGGYGGYGGYWWGWWGWWGRRRRRRRRRW...    True            3
# 1  YYYYYYOOOWOOWOOWOOGGGGGGGGGRRRWWWWWWRRYRRYRRYB...    True            1
# 2  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...    True            3
# 3  BYYBYYBYYOOOOOOOOOYGGYGGYGGGWWGWWGWWRRRRRRRRRB...   False           50
# 4  GYYGYYGYYOOOOOOOOOWGGWGGWGGBWWBWWBWWRRRRRRRRRB...   False           50
#
#    total_reward  timeout termination_reason  \
# ...

# %%
solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['start_state'].value_counts())
# Out:
#                  episode_id   model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth1-episode0  depth_1_onehot               1                R'
# 1  eval_001-depth1-episode1  depth_1_onehot               1                F'
# 2  eval_001-depth1-episode2  depth_1_onehot               1                 U
# 5  eval_001-depth1-episode5  depth_1_onehot               1                 D
# 6  eval_001-depth1-episode6  depth_1_onehot               1                 B
#
#                                          start_state  solved  total_steps  \
# 0  YYBYYBYYBOOOOOOOOOGGYGGYGGYWWGWWGWWGRRRRRRRRRW...    True            3
# 1  YYYYYYOOOWOOWOOWOOGGGGGGGGGRRRWWWWWWRRYRRYRRYB...    True            1
# 2  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...    True            3
# 5  YYYYYYYYYOOOOOOGGGGGGGGGRRRWWWWWWWWWRRRRRRBBBB...    True            1
# 6  OOOYYYYYYOOWOOWOOWGGGGGGGGGWWWWWWRRRYRRYRRYRRB...    True            3
#
# ...

# %%
df = pd.read_parquet("../data/processed/training/parquet/depth_1.parquet")
print(df["scramble_moves"].value_counts())
# Out:
# scramble_moves
# D     1
# U     1
# F     1
# L     1
# D'    1
# F'    1
# L'    1
# R'    1
# R     1
# U'    1
# B'    1
# B     1
# Name: count, dtype: int64

# %%
episodes = pd.read_parquet("../data/logs/depth_1_onehot_2000/eval_001/depth_1/episodes.parquet")
display(episodes.head())
# Out:
#                  episode_id        model_version  scramble_depth  \
# 0  eval_001-depth1-episode0  depth_1_onehot_2000               1
# 1  eval_001-depth1-episode1  depth_1_onehot_2000               1
# 2  eval_001-depth1-episode2  depth_1_onehot_2000               1
# 3  eval_001-depth1-episode3  depth_1_onehot_2000               1
# 4  eval_001-depth1-episode4  depth_1_onehot_2000               1
#
#   scramble_sequence                                        start_state  \
# 0                 D  YYYYYYYYYOOOOOOGGGGGGGGGRRRWWWWWWWWWRRRRRRBBBB...
# 1                 U  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...
# 2                 F  YYYYYYRRRYOOYOOYOOGGGGGGGGGOOOWWWWWWRRWRRWRRWB...
# 3                 L  BYYBYYBYYOOOOOOOOOYGGYGGYGGGWWGWWGWWRRRRRRRRRB...
# 4                D'  YYYYYYYYYOOOOOOBBBGGGGGGOOOWWWWWWWWWRRRRRRGGGB...
#
#    solved  total_steps  total_reward  timeout termination_reason  \
# 0    True            1          99.0    False             solved
# ...

# %%
solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['start_state'].value_counts())
# Out:
#                  episode_id        model_version  scramble_depth  \
# 0  eval_001-depth1-episode0  depth_1_onehot_2000               1
# 1  eval_001-depth1-episode1  depth_1_onehot_2000               1
# 2  eval_001-depth1-episode2  depth_1_onehot_2000               1
# 4  eval_001-depth1-episode4  depth_1_onehot_2000               1
# 5  eval_001-depth1-episode5  depth_1_onehot_2000               1
#
#   scramble_sequence                                        start_state  \
# 0                 D  YYYYYYYYYOOOOOOGGGGGGGGGRRRWWWWWWWWWRRRRRRBBBB...
# 1                 U  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...
# 2                 F  YYYYYYRRRYOOYOOYOOGGGGGGGGGOOOWWWWWWRRWRRWRRWB...
# 4                D'  YYYYYYYYYOOOOOOBBBGGGGGGOOOWWWWWWWWWRRRRRRGGGB...
# 5                F'  YYYYYYOOOWOOWOOWOOGGGGGGGGGRRRWWWWWWRRYRRYRRYB...
#
#    solved  total_steps  total_reward  timeout termination_reason moves_taken  \
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_2_onehot/v001/history.csv")

display(history.head())
print(history.shape)
# Out:
#    approx_kl  clip_fraction   entropy  explained_variance      loss  \
# 0   0.004274       0.025586  2.481479           -0.057582 -0.040789
# 1   0.005242       0.056885  2.475433            0.020987 -0.048012
# 2   0.007213       0.081982  2.462716            0.062328 -0.051469
# 3   0.009122       0.137402  2.444471           -0.022117 -0.057795
# 4   0.011967       0.192188  2.412887            0.132290 -0.059176
#
#    mean_episode_length  mean_episode_reward  policy_loss  timesteps  \
# 0                 9.57              -0.1772    -0.021377       2048
# 1                 9.06              -0.1086    -0.030735       4096
# 2                 9.16              -0.1161    -0.035497       6144
# 3                 9.39              -0.1524    -0.042527       8192
# 4                 9.29              -0.1319    -0.047032      10240
#
#    train_solve_rate  value_loss  \
# 0              0.05    0.010806
# 1              0.11    0.014955
# 2              0.10    0.017311
# ...

# %%
fig1 = px.bar(history, x='timesteps', y='mean_episode_reward')
fig1.show()

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_onehot/v009/history.csv")

display(history.head())
print(history.shape)

fig1 = px.bar(history, x='timesteps', y='train_solve_rate')
fig1.show()
# Out:
#    approx_kl  clip_fraction   entropy  explained_variance      loss  \
# 0   0.002966       0.021094  2.480210           -0.025382 -0.037252
# 1   0.008856       0.118555  2.464976            0.019126 -0.047871
# 2   0.018618       0.251221  2.400262            0.043592 -0.054333
# 3   0.023883       0.371143  2.273853            0.128468 -0.053463
# 4   0.025069       0.460791  2.098712            0.232203 -0.056918
#
#    mean_episode_length  mean_episode_reward  policy_loss  timesteps  \
# 0                 4.80              -0.1060    -0.026141       2048
# 1                 4.42               0.0208    -0.040258       4096
# 2                 4.30               0.0655    -0.056089       6144
# 3                 3.78               0.2192    -0.084891       8192
# 4                 3.16               0.4034    -0.106189      10240
#
#    train_solve_rate  value_loss  \
# 0              0.05    0.027382
# 1              0.16    0.034075
# 2              0.20    0.051517
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_5_onehot/v001/history.csv")

history_5 = history[history['curriculum_depth'] == 1]

print(history_5.shape)
solve_rate = history.copy()

solve_rate['avg_solve'] = solve_rate.groupby('curriculum_depth')['train_solve_rate'].transform('mean')

display(solve_rate[['curriculum_depth', 'avg_solve']])

depth_stats = solve_rate.groupby('curriculum_depth').agg(
    depth_count=('curriculum_depth', 'count'),
    avg_solve=('train_solve_rate', 'mean')
)

display(depth_stats)

display(history_5.head())
print(history.shape)
print(history['curriculum_depth'].value_counts())

fig1 = px.line(history_5, x='timesteps', y='train_solve_rate')
fig1.show()
# Out:
# (5, 17)
#      curriculum_depth  avg_solve
# 0                   1   0.248000
# 1                   1   0.248000
# 2                   1   0.248000
# 3                   1   0.248000
# 4                   1   0.248000
# ..                ...        ...
# 484                 5   0.864352
# 485                 5   0.864352
# 486                 5   0.864352
# 487                 5   0.864352
# 488                 5   0.864352
#
# [489 rows x 2 columns]
#                   depth_count  avg_solve
# curriculum_depth
# 1                           5   0.248000
# 2                           5   0.668000
# 3                          10   0.838000
# 4                         122   0.857377
# 5                         347   0.864352
#    timesteps  policy_loss  value_loss   entropy  approx_kl  clip_fraction  \
# 0       2048    -0.034626    0.040052  2.478456   0.004873       0.060498
# 1       4096    -0.052345    0.048615  2.438512   0.015399       0.203027
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_3_onehot/v001/history.csv")

display(history.head())
print(history.shape)

fig1 = px.bar(history, x='timesteps', y='mean_episode_reward')
fig1.show()
# Out:
#    timesteps  policy_loss  value_loss   entropy  approx_kl  clip_fraction  \
# 0       2048    -0.027216    0.003837  2.481435   0.003694       0.025146
# 1       4096    -0.060968    0.001468  2.471692   0.008021       0.118506
# 2       6144    -0.046633    0.004367  2.460479   0.007292       0.100293
# 3       8192    -0.048295    0.005037  2.445252   0.008451       0.119873
# 4      10240    -0.055671    0.004503  2.431901   0.009390       0.152148
#
#        loss  explained_variance  mean_episode_reward  mean_episode_length  \
# 0 -0.050111           -0.187237              -0.3589                19.64
# 1 -0.084951            0.040781              -0.3765                20.00
# 2 -0.069055            0.179114              -0.3348                19.43
# 3 -0.070229            0.079202              -0.3437                19.47
# 4 -0.077738            0.070343              -0.3156                19.06
#
#    train_solve_rate  timeout_rate  inverse_move_rate  \
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_10_onehot/v004/history.csv")

display(history.head())
print(history.shape)

fig1 = px.bar(history, x='timesteps', y='mean_episode_reward')
fig1.show()
# Out:
#    timesteps  policy_loss  value_loss   entropy  approx_kl  clip_fraction  \
# 0       2048    -0.034626    0.040052  2.478456   0.004873       0.060498
# 1       4096    -0.052345    0.048615  2.438512   0.015399       0.203027
# 2       6144    -0.082350    0.099016  2.311139   0.030721       0.412158
# 3       8192    -0.095648    0.176465  2.102715   0.028169       0.433105
# 4      10240    -0.084767    0.225571  1.843426   0.017972       0.335449
#
#        loss  explained_variance  mean_episode_reward  mean_episode_length  \
# 0 -0.039385           -0.018794              -0.0342                 2.82
# 1 -0.052423            0.009953              -0.0474                 2.84
# 2 -0.055954            0.052768               0.0530                 2.70
# 3 -0.028443            0.148479               0.2839                 2.36
# 4  0.009585            0.203968               0.4382                 2.18
#
#    train_solve_rate  timeout_rate  inverse_move_rate  curriculum_depth  \
# ...

# %%
episodes = pd.read_parquet("../data/logs/depth_1_3_v1/eval_001/depth_1/episodes.parquet")
display(episodes.head())


solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['start_state'].value_counts())
print(solved['scramble_depth'].value_counts())
# Out:
#                  episode_id model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth1-episode0  depth_1_3_v1               1                 D
# 1  eval_001-depth1-episode1  depth_1_3_v1               1                 U
# 2  eval_001-depth1-episode2  depth_1_3_v1               1                 F
# 3  eval_001-depth1-episode3  depth_1_3_v1               1                 L
# 4  eval_001-depth1-episode4  depth_1_3_v1               1                D'
#
#                                          start_state  solved  total_steps  \
# 0  YYYYYYYYYOOOOOOGGGGGGGGGRRRWWWWWWWWWRRRRRRBBBB...    True            1
# 1  YYYYYYYYYBBBOOOOOOOOOGGGGGGWWWWWWWWWGGGRRRRRRR...    True            3
# 2  YYYYYYRRRYOOYOOYOOGGGGGGGGGOOOWWWWWWRRWRRWRRWB...    True            1
# 3  BYYBYYBYYOOOOOOOOOYGGYGGYGGGWWGWWGWWRRRRRRRRRB...    True            1
# 4  YYYYYYYYYOOOOOOBBBGGGGGGOOOWWWWWWWWWRRRRRRGGGB...    True            1
#
# ...

# %%
episodes = pd.read_parquet("../data/logs/depth_1_10_v7/eval_001/depth_5/episodes.parquet")
display(episodes.head())

print(episodes['start_state'].value_counts())
print(episodes['scramble_depth'].value_counts())


solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['start_state'].value_counts())
print(solved['scramble_depth'].value_counts())
# Out:
#                  episode_id  model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth5-episode0  depth_1_10_v7               5        B L B D L'
# 1  eval_001-depth5-episode1  depth_1_10_v7               5     F' D' F' B R'
# 2  eval_001-depth5-episode2  depth_1_10_v7               5      L B' D' F L'
# 3  eval_001-depth5-episode3  depth_1_10_v7               5      L' F' L U L'
# 4  eval_001-depth5-episode4  depth_1_10_v7               5         D L L B B
#
#                                          start_state  solved  total_steps  \
# 0  OWWYYYBYYOOROORYGGYGGRGGRRRGGGBWWBWWYRRYRWOOWB...   False           50
# 1  OOYYYRWWRWWROOBWWRGGBGGYGGBYYORWORRWYROYROYGOG...   False           50
# 2  ORROYYYRRBOBYOYYBBBYYWGGGGGROOBWOWGOWWORRGGWYW...   False           50
# 3  WYYGYYOYYBBBWOOBOOGOOGGGWWWRRRBWWRWWGRYGRYGRGR...   False           50
# 4  WWYWYYWYYOOROORGGBOGGBGGBRRYWWYWWYYWGBBORRORRG...   False           50
#
#    total_reward  timeout termination_reason  \
# ...

# %%
episodes = pd.read_parquet("../data/logs/depth_1_2_v1/eval_001/depth_2/episodes.parquet")
display(episodes.head())

print(episodes['start_state'].value_counts())
print(episodes['scramble_depth'].value_counts())


solved = episodes[episodes['solved'] == True]

display(solved.head())

print(solved['start_state'].value_counts())
print(solved['scramble_depth'].value_counts())
# Out:
#                  episode_id model_version  scramble_depth scramble_sequence  \
# 0  eval_001-depth2-episode0  depth_1_2_v1               2              F' L
# 1  eval_001-depth2-episode1  depth_1_2_v1               2              L U'
# 2  eval_001-depth2-episode2  depth_1_2_v1               2             F' D'
# 3  eval_001-depth2-episode3  depth_1_2_v1               2              F' B
# 4  eval_001-depth2-episode4  depth_1_2_v1               2              B R'
#
#                                          start_state  solved  total_steps  \
# 0  BYYBYYBOOWOOWOOWOOYGGYGGOGGGRRGWWGWWRRRRRRYYYB...    True            2
# 1  YYYYYYBBBYGGOOOOOORRRYGGYGGGWWGWWGWWBBWRRRRRRO...    True            2
# 2  YYYYYYOOOWOOWOOBBBGGGGGGWOORWWRWWRWWRRYRRYGGGB...    True            2
# 3  OOOYYYOOOWOWWOWWOWGGGGGGGGGRRRWWWRRRYRYYRYYRYB...    True            2
# 4  OOBYYBYYBWWWOOOOOOGGOGGYGGYWWGWWGRRGYRRYRRYRRR...    True            2
#
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_10_onehot/v004/history.csv")

history_5 = history[history['curriculum_depth'] == 6]

print(history_5.shape)
solve_rate = history.copy()

solve_rate['avg_solve'] = solve_rate.groupby('curriculum_depth')['train_solve_rate'].transform('mean')

display(solve_rate[['curriculum_depth', 'avg_solve']])

depth_stats = solve_rate.groupby('curriculum_depth').agg(
    depth_count=('curriculum_depth', 'count'),
    avg_solve=('train_solve_rate', 'mean'),
    avg_timeout=('timeout_rate', 'mean'),
    min_timeout=('timeout_rate', 'min'),
    max_timeout=('timeout_rate', 'max'),
    ep_length=('mean_episode_length', 'mean'),
    
)

display(depth_stats)

display(history_5.head())
print(history.shape)
print(history['curriculum_depth'].value_counts())

fig1 = px.line(history_5, x='timesteps', y='entropy')
fig1.show()
# Out:
# (522, 17)
#      curriculum_depth  avg_solve
# 0                   1   0.248000
# 1                   1   0.248000
# 2                   1   0.248000
# 3                   1   0.248000
# 4                   1   0.248000
# ..                ...        ...
# 972                 6   0.741322
# 973                 6   0.741322
# 974                 6   0.741322
# 975                 6   0.741322
# 976                 6   0.741322
#
# [977 rows x 2 columns]
#                   depth_count  avg_solve  avg_timeout  min_timeout  \
# curriculum_depth
# 1                           5   0.248000     0.752000         0.48
# 2                           5   0.668000     0.332000         0.16
# 3                           5   0.804000     0.196000         0.15
# 4                         147   0.854218     0.145782         0.03
# 5                         293   0.856553     0.143447         0.04
# 6                         522   0.741322     0.258678         0.12
#
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_10_onehot/v005/history.csv")

history_5 = history[history['curriculum_depth'] == 6]

print(history_5.shape)
solve_rate = history.copy()

depth_stats = solve_rate.groupby('curriculum_depth').agg(
    depth_count=('curriculum_depth', 'count'),
    avg_solve=('train_solve_rate', 'mean'),
    max_solve=('train_solve_rate', 'max'),
    avg_timeout=('timeout_rate', 'mean'),
    min_timeout=('timeout_rate', 'min'),
    max_timeout=('timeout_rate', 'max'),
    ep_length=('mean_episode_length', 'mean'),
    
)

display(depth_stats)

display(history_5.head())
print(history.shape)
print(history['curriculum_depth'].value_counts())

fig1 = px.line(history_5, x='timesteps', y='entropy')
fig1.show()
# Out:
# (1041, 17)
#                   depth_count  avg_solve  max_solve  avg_timeout  min_timeout  \
# curriculum_depth
# 1                           5   0.248000       0.52     0.752000         0.48
# 2                           5   0.668000       0.84     0.332000         0.16
# 3                           5   0.804000       0.85     0.196000         0.15
# 4                         127   0.843386       0.95     0.156614         0.05
# 5                         317   0.851640       0.96     0.148360         0.04
# 6                        1041   0.680961       0.85     0.319039         0.15
# 7                         942   0.517452       0.67     0.482548         0.33
#
#                   max_timeout  ep_length
# curriculum_depth
# 1                        0.92   2.580000
# 2                        0.59   2.840000
# 3                        0.25   3.230000
# 4                        0.35   3.952520
# 5                        0.33   4.617066
# 6                        0.55   7.799760
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_10_onehot/v007/history.csv")

history_5 = history[history['curriculum_depth'] == 6]

print(history_5.shape)
solve_rate = history.copy()

depth_stats = solve_rate.groupby('curriculum_depth').agg(
    depth_count=('curriculum_depth', 'count'),
    avg_solve=('train_solve_rate', 'mean'),
    max_solve=('train_solve_rate', 'max'),
    avg_timeout=('timeout_rate', 'mean'),
    min_timeout=('timeout_rate', 'min'),
    max_timeout=('timeout_rate', 'max'),
    ep_length=('mean_episode_length', 'mean'),
    
)

display(depth_stats)

display(history_5.head())
print(history.shape)
print(history['curriculum_depth'].value_counts())

fig1 = px.line(history_5, x='timesteps', y='entropy')
fig1.show()
# Out:
# (1128, 17)
#                   depth_count  avg_solve  max_solve  avg_timeout  min_timeout  \
# curriculum_depth
# 1                           5   0.258000       0.57     0.742000         0.43
# 2                           5   0.608000       0.79     0.392000         0.21
# 3                          10   0.791000       0.89     0.209000         0.11
# 4                          83   0.838434       0.96     0.161566         0.04
# 5                         225   0.841244       0.94     0.158756         0.06
# 6                        1128   0.666596       0.86     0.333404         0.14
# 7                         986   0.404422       0.65     0.595578         0.35
#
#                   max_timeout  ep_length
# curriculum_depth
# 1                        0.91   2.532000
# 2                        0.61   3.042000
# 3                        0.33   3.275000
# 4                        0.36   4.038795
# 5                        0.30   4.766089
# 6                        0.58   7.985798
# ...

# %%
history = pd.read_csv("../models/artifacts/ppo/depth_1_5_onehot/v005/history.csv")

history_5 = history[history['curriculum_depth'] == 5]

print(history_5.shape)
solve_rate = history.copy()

depth_stats = solve_rate.groupby('curriculum_depth').agg(
    depth_count=('curriculum_depth', 'count'),
    avg_solve=('train_solve_rate', 'mean'),
    max_solve=('train_solve_rate', 'max'),
    avg_timeout=('timeout_rate', 'mean'),
    min_timeout=('timeout_rate', 'min'),
    max_timeout=('timeout_rate', 'max'),
    ep_length=('mean_episode_length', 'mean'),
    
)

display(depth_stats)

display(history_5.head())
print(history.shape)
print(history['curriculum_depth'].value_counts())

fig1 = px.line(history_5, x='timesteps', y='train_solve_rate')
fig1.show()
# Out:
# (874, 17)
#                   depth_count  avg_solve  max_solve  avg_timeout  min_timeout  \
# curriculum_depth
# 1                           5   0.258000       0.57     0.742000         0.43
# 2                           5   0.608000       0.79     0.392000         0.21
# 3                          10   0.791000       0.89     0.209000         0.11
# 4                          83   0.838434       0.96     0.161566         0.04
# 5                         874   0.907094       1.00     0.092906         0.00
#
#                   max_timeout  ep_length
# curriculum_depth
# 1                        0.91   2.532000
# 2                        0.61   3.042000
# 3                        0.33   3.275000
# 4                        0.36   4.038795
# 5                        0.30   4.275915
#      timesteps  policy_loss  value_loss   entropy  approx_kl  clip_fraction  \
# 103     212992    -0.053302    0.026282  0.705782   0.025928       0.234521
# ...
